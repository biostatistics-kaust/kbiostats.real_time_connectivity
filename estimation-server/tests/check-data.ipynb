# %%
# %matplotlib inline
import os, sys, time
import numpy as np
import matplotlib.pyplot as plt
os.listdir(".")
# Out:
# ['.ipynb_checkpoints',
#  'out-beta.npy',
#  'out-omega.npy',
#  'out-sigma.npy',
#  'Untitled.ipynb']

# %%
def plot(X):
    plt.imshow(X)
    plt.title(str(X.shape))
    plt.colorbar()
beta = np.load("out-beta.npy")
sigma = np.load("out-sigma.npy")
omega = np.load("out-omega.npy")
plot(beta)
plt.show()
plot(sigma)
plt.show()
plot(omega)
plt.show()

# %%
249/64
# Out:
# 3.890625
